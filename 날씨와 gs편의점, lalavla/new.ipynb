# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cv = pd.read_excel('0717_편의점.xlsx', index_col=0)

# %%
la = pd.read_excel('0717_랄라블라.xlsx', index_col=0)

# %%
cv_col = cv.columns[13:]
cv_col

# %%
la_col = la.columns[13:]
la_col

# %%
AR(p) = ARIMA(p, 0, 0)
MA(q) = ARIMA(0, 0, q)
ARMA(p, q) = ARIMA(p, 0, q)

# %%
final = pd.read_excel('대건아.xlsx')

# %%
clean = pd.read_excel('final.xlsx', header=0, index_col=0, squeeze=True)

# %%
x = 
y =

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(cv,la, test_size=0.1, train_size=0.9, random_state=10, shuffle=False)

# %%
clean.head(1)
# Out:
# 날짜
# 2016-01-15    12304.6
# Name: 훼이셜클렌저_MA15, dtype: float64

# %%
final.plot(x='날짜',y='훼이셜클렌저_MA15')
# Out:
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(clean)
plot_pacf(clean)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

diff_1=clean.diff(periods=1).iloc[1:]
diff_1.plot()
plot_acf(diff_1)
plot_pacf(diff_1)
plt.show()
# Out:
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(clean, order=(0,1,1))
model_fit = model.fit(trend='c',full_output=True, disp=1)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:          D.훼이셜클렌저_MA15   No. Observations:                 1081
# Model:                 ARIMA(0, 1, 1)   Log Likelihood               -8280.346
# Method:                       css-mle   S.D. of innovations            513.288
# Date:                Thu, 18 Jul 2019   AIC                          16566.692
# Time:                        16:16:43   BIC                          16581.649
# Sample:                    01-16-2016   HQIC                         16572.355
#                          - 12-31-2018
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1417     23.035      0.006      0.995     -45.006      45.290
# ma.L1.D.훼이셜클렌저_MA15     0.4760      0.020     23.582      0.000       0.436       0.516
#                                     Roots
# ...

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(clean, order=(0,1,1))
model_fit = model.fit(trend='nc',full_output=True, disp=1)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:          D.훼이셜클렌저_MA15   No. Observations:                 1081
# Model:                 ARIMA(0, 1, 1)   Log Likelihood               -8280.346
# Method:                       css-mle   S.D. of innovations            513.288
# Date:                Thu, 18 Jul 2019   AIC                          16564.692
# Time:                        16:16:43   BIC                          16574.663
# Sample:                    01-16-2016   HQIC                         16568.467
#                          - 12-31-2018
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ma.L1.D.훼이셜클렌저_MA15     0.4760      0.020     23.582      0.000       0.436       0.516
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# ...

# %%
model_fit.plot_predict()
# Out:
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49500 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 53364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47116 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
fore = model_fit.forecast(steps=1)
print(fore)
# Out:
# (array([12444.14570652]), array([513.28800225]), array([[11438.1197084 , 13450.17170463]]))

# %%
pre = fore - mask['마스크_MA24']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-81e5f4f11eb5> in <module>
# ----> 1 pre = fore - mask['마스크_MA24']
#
# NameError: name 'mask' is not defined

# %%
for i in cv_col:
    m = 2
    temp = cv[i].rolling(m).mean()
    print('\n컬럼 : {}\n'.format(i))
    while m < 10:
        m += 1
        temp = cv[i].rolling(m).mean()
        print('이동평균, 첨도 값은 : {}, {}'.format(m, temp.kurtosis()))

# %%
for i in la_col:
    m = 2
    temp = la[i].rolling(m).mean()
    print('\n컬럼 : {}\n'.format(i))
    while m < 5:
        m += 1
        temp = la[i].rolling(m).mean()
        print('이동평균, 첨도 값은 : {}, {}'.format(m, temp.kurtosis()))

# %%
for i in cv_col:
    cv['{}_mean'.format(i)] = round(cv[i].rolling(window=7).mean(), 1)

# %%
for i in la_col:
    la['{}_mean'.format(i)] = round(la[i].rolling(window=7).mean(), 1)

# %%
cv.head()

# %%
la.head()

# %%
cv['과자'].kurtosis()

# %%
cv.iloc[6:,25:37].kurtosis()

# %%
la.iloc[6:,23:35].kurtosis()

# %%
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['font.size'] = 12
plt.style.use(['dark_background'])

# %%
plt.figure(figsize=(20,60))
for i,j in enumerate(cv_col):
    plt.subplot(12,1,i+1)
    plt.title(j)
    plt.plot(cv[j], color='w', label=j)
    plt.plot(cv['{}_mean'.format(j)], color='r', label='{}_mean'.format(j))
    plt.legend()

# %%
plt.figure(figsize=(20,50))
for i,j in enumerate(la_col):
    plt.subplot(10,1,i+1)
    plt.title(j)
    plt.plot(la[j], color='w', label=j)
    plt.plot(la['{}_mean'.format(j)], color='r', label='{}_mean'.format(j))
    plt.legend()
