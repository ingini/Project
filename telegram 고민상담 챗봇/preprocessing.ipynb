# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('루리웹.csv')

# %%
sin = df[df['title'].str.contains('신체')]
esung = df[df['title'].str.contains('이성')]
con = df[df['title'].str.contains('컴플렉스')]
hobby = df[df['title'].str.contains('취미')]
inseang = df[df['title'].str.contains('인생')]
study = df[df['title'].str.contains('학업')]
friend = df[df['title'].str.contains('친구')]

# %%
# 신체 : 0 , 이성 : 1, 컴플렉스 : 2, 취미 : 3, 인생 : 4, 학업 : 5, 친구 : 6
sin['label'] = 0
esung['label'] = 1
con['label'] = 2
hobby['label']= 3
inseang['label'] = 4
study['label'] = 5
friend['label'] = 6
# Out:
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
join = sin.append([esung, con, hobby, inseang, study, friend])

# %%
join.reset_index(inplace=True)

# %%
join.drop('index', axis= 1, inplace= True)

# %%
join
# Out:
#                                              title  \
# 0               [신체] 진짜 뚱뚱한 사람들 보면 맨처음 느끼는게 혐오감인가요
# 1                           [신체] 머리털이 자꾸 빠져 고민 입니다
# 2                    [신체] 성욕을 완전히 영구적으로 제거할 수 없나요?
# 3                                 [신체] 손 떨림 있으신가요?
# 4                   [신체] 채용검진비 40만원... 받아야 하는 겁니까?
# ...                                            ...
# 8532                     [이성] 남자친구가 장기출장을 갈 것 같습니다
# 8533  [인생] 어머니의 남자친구가 어머니의 선물 수령인을 제 이름으로 하고 보냅니다.
# 8534               [친구] [실종] 사람을 찾습니다. (클릭 부탁드려요.)
# 8535                   [이성] 여자친구가 업소에서 일하기 시작했습니다.
# 8536           [친구] 오토바이 작게 사고가 났는데 제가 보상해줘야 하나요??
#
#                                                    body  label
# 0     제가 좀 많이 뚱뚱합니다. 걍 모태돼지인데 럭비선수로 학창시절 보내다가 정말 하고 ...      0
# 1     프로페시아 3주차 인데 처음 복용 했을때는 안 빠지는거 같다가 최근 이틀간 정예병이...      0
# 2     여태까지 27년동안 여자한번 못만나봤고 앞으로도 없을 상황인데성욕이 너무 쓸데가 없...      0
# 3     저는 지금 정신건강의학과를 다니면서 정신과약과 지금 손떨림방지 약을 먹고 있습니다....      0
# 4     이번에 새 회사 입사하게 돼서채용검진을 받았거든요첫날가서 기본 검진 받는데10만원 ...      0
# ...                                                 ...    ...
# 8532  남친이 여름들어서 엄청 바빠졌어요. 기본 9-10시에 퇴근하고 주말 이틀 다 출근하...      6
# 8533  아버지가 돌아기신후 10년 사이에 어머니에게는 남자 친구가 세 분 있으셨는데요이분들...      6
# 8534  저는 이 분의 직장 동료입니다.이틀간 손에 일이 안잡히네요. 제가 하는 sns 모두...      6
# 8535  만난지는 두달 밖에 안되었습니다.. 오래만난 연인과 헤어진 이후에 1년동안 정말 많...      6
# 8536  제가 오토바이를 탄건아니고요신호없는 횡단보도 옆 두발자국정도?  폰보면 길건너고있었...      6
#
# [8537 rows x 3 columns]

# %%
i=0

for i in range(len(join)):
    join['name'][i] = join['title'][i][5:]
    i += 1
# Out:
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
join['name']
# Out:
# 0                 진짜 뚱뚱한 사람들 보면 맨처음 느끼는게 혐오감인가요
# 1                             머리털이 자꾸 빠져 고민 입니다
# 2                      성욕을 완전히 영구적으로 제거할 수 없나요?
# 3                                   손 떨림 있으신가요?
# 4                     채용검진비 40만원... 받아야 하는 겁니까?
#                          ...
# 8532                       남자친구가 장기출장을 갈 것 같습니다
# 8533    어머니의 남자친구가 어머니의 선물 수령인을 제 이름으로 하고 보냅니다.
# 8534                 [실종] 사람을 찾습니다. (클릭 부탁드려요.)
# 8535                     여자친구가 업소에서 일하기 시작했습니다.
# 8536             오토바이 작게 사고가 났는데 제가 보상해줘야 하나요??
# Name: name, Length: 8537, dtype: object

# %%
join2 = join.copy()

# %%
join2
# Out:
#                                              title  \
# 0               [신체] 진짜 뚱뚱한 사람들 보면 맨처음 느끼는게 혐오감인가요
# 1                           [신체] 머리털이 자꾸 빠져 고민 입니다
# 2                    [신체] 성욕을 완전히 영구적으로 제거할 수 없나요?
# 3                                 [신체] 손 떨림 있으신가요?
# 4                   [신체] 채용검진비 40만원... 받아야 하는 겁니까?
# ...                                            ...
# 8532                     [이성] 남자친구가 장기출장을 갈 것 같습니다
# 8533  [인생] 어머니의 남자친구가 어머니의 선물 수령인을 제 이름으로 하고 보냅니다.
# 8534               [친구] [실종] 사람을 찾습니다. (클릭 부탁드려요.)
# 8535                   [이성] 여자친구가 업소에서 일하기 시작했습니다.
# 8536           [친구] 오토바이 작게 사고가 났는데 제가 보상해줘야 하나요??
#
#                                                    body  label  \
# 0     제가 좀 많이 뚱뚱합니다. 걍 모태돼지인데 럭비선수로 학창시절 보내다가 정말 하고 ...      0
# 1     프로페시아 3주차 인데 처음 복용 했을때는 안 빠지는거 같다가 최근 이틀간 정예병이...      0
# 2     여태까지 27년동안 여자한번 못만나봤고 앞으로도 없을 상황인데성욕이 너무 쓸데가 없...      0
# 3     저는 지금 정신건강의학과를 다니면서 정신과약과 지금 손떨림방지 약을 먹고 있습니다....      0
# 4     이번에 새 회사 입사하게 돼서채용검진을 받았거든요첫날가서 기본 검진 받는데10만원 ...      0
# ...                                                 ...    ...
# 8532  남친이 여름들어서 엄청 바빠졌어요. 기본 9-10시에 퇴근하고 주말 이틀 다 출근하...      6
# 8533  아버지가 돌아기신후 10년 사이에 어머니에게는 남자 친구가 세 분 있으셨는데요이분들...      6
# 8534  저는 이 분의 직장 동료입니다.이틀간 손에 일이 안잡히네요. 제가 하는 sns 모두...      6
# 8535  만난지는 두달 밖에 안되었습니다.. 오래만난 연인과 헤어진 이후에 1년동안 정말 많...      6
# 8536  제가 오토바이를 탄건아니고요신호없는 횡단보도 옆 두발자국정도?  폰보면 길건너고있었...      6
#
#                                          name
# 0               진짜 뚱뚱한 사람들 보면 맨처음 느끼는게 혐오감인가요
# 1                           머리털이 자꾸 빠져 고민 입니다
# 2                    성욕을 완전히 영구적으로 제거할 수 없나요?
# 3                                 손 떨림 있으신가요?
# 4                   채용검진비 40만원... 받아야 하는 겁니까?
# ...                                       ...
# 8532                     남자친구가 장기출장을 갈 것 같습니다
# 8533  어머니의 남자친구가 어머니의 선물 수령인을 제 이름으로 하고 보냅니다.
# 8534               [실종] 사람을 찾습니다. (클릭 부탁드려요.)
# 8535                   여자친구가 업소에서 일하기 시작했습니다.
# 8536           오토바이 작게 사고가 났는데 제가 보상해줘야 하나요??
#
# [8537 rows x 4 columns]

# %%
join2.drop(['title', 'body'], axis='columns', inplace=True)

# %%
join2
# Out:
#       label                                     name
# 0         0            진짜 뚱뚱한 사람들 보면 맨처음 느끼는게 혐오감인가요
# 1         0                        머리털이 자꾸 빠져 고민 입니다
# 2         0                 성욕을 완전히 영구적으로 제거할 수 없나요?
# 3         0                              손 떨림 있으신가요?
# 4         0                채용검진비 40만원... 받아야 하는 겁니까?
# ...     ...                                      ...
# 8532      6                     남자친구가 장기출장을 갈 것 같습니다
# 8533      6  어머니의 남자친구가 어머니의 선물 수령인을 제 이름으로 하고 보냅니다.
# 8534      6               [실종] 사람을 찾습니다. (클릭 부탁드려요.)
# 8535      6                   여자친구가 업소에서 일하기 시작했습니다.
# 8536      6           오토바이 작게 사고가 났는데 제가 보상해줘야 하나요??
#
# [8537 rows x 2 columns]

# %%
join2['label2'] = 0

# %%
join2
# Out:
#       label                                     name  label2
# 0         0            진짜 뚱뚱한 사람들 보면 맨처음 느끼는게 혐오감인가요       0
# 1         0                        머리털이 자꾸 빠져 고민 입니다       0
# 2         0                 성욕을 완전히 영구적으로 제거할 수 없나요?       0
# 3         0                              손 떨림 있으신가요?       0
# 4         0                채용검진비 40만원... 받아야 하는 겁니까?       0
# ...     ...                                      ...     ...
# 8532      6                     남자친구가 장기출장을 갈 것 같습니다       0
# 8533      6  어머니의 남자친구가 어머니의 선물 수령인을 제 이름으로 하고 보냅니다.       0
# 8534      6               [실종] 사람을 찾습니다. (클릭 부탁드려요.)       0
# 8535      6                   여자친구가 업소에서 일하기 시작했습니다.       0
# 8536      6           오토바이 작게 사고가 났는데 제가 보상해줘야 하나요??       0
#
# [8537 rows x 3 columns]

# %%
join2.to_csv('문장labeling.csv',index=False, encoding='euc-kr')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-57-da286b1b0ab3> in <module>
# ----> 1 join2.to_csv('문장labeling.csv',index=False, encoding='euc-kr')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     200                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     201
# --> 202             self._save()
#     203
#     204         finally:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     322                 break
#     323
# --> 324             self._save_chunk(start_i, end_i)
#     325
#     326     def _save_chunk(self, start_i, end_i):
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     354         )
#     355
# --> 356         libwriters.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#
# pandas\_libs\writers.pyx in pandas._libs.writers.write_csv_rows()
#
# UnicodeEncodeError: 'euc_kr' codec can't encode character '\ufeff' in position 2: illegal multibyte sequence

# %%
import chardet
print (chardet.detect (join2['name']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-d0a48d7cc167> in <module>
#       1 import chardet
# ----> 2 print (chardet.detect (join2['name']))
#
# ~\Anaconda3\lib\site-packages\chardet\__init__.py in detect(byte_str)
#      32         if not isinstance(byte_str, bytes):
#      33             raise TypeError('Expected object of type bytes or bytearray, got: '
# ---> 34                             '{0}'.format(type(byte_str)))
#      35         else:
#      36             byte_str = bytearray(byte_str)
#
# TypeError: Expected object of type bytes or bytearray, got: <class 'pandas.core.series.Series'>
