# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train_wk_sum.csv')

# %%
df.head()
# Out:
#    acc_id  playtime_1  npc_kill_1  solo_exp_1  party_exp_1  quest_exp_1  \
# 0       2   22.919696    0.000000    0.000000     0.000000     0.000000
# 1       8    4.987936   26.808113   28.720862     0.000000     0.650061
# 2      17    5.406914   25.931158    4.197880     1.086304     0.700796
# 3      20    5.526287   27.285960    0.204564     0.025327     0.004013
# 4      21    6.048253    4.379366   14.917062     0.000000     9.242806
#
#    rich_monster_1    death_1   revive_1  exp_recovery_1  ...  \
# 0             0.0   0.000000   0.000000             0.0  ...
# 1             1.0  88.763931  89.288620             0.0  ...
# 2             4.0   0.491767   0.494674             0.0  ...
# 3             1.0   0.000000   0.000000             0.0  ...
# 4             0.0   0.000000   0.000000             0.0  ...
#
#    combat_same_pledge_cnt_3  combat_etc_cnt_3  combat_num_opponent_3  \
# 0                       0.0          0.000000               0.000000
# ...

# %%
play = df

# %%
play.columns
# Out:
# Index(['acc_id', 'playtime_1', 'npc_kill_1', 'solo_exp_1', 'party_exp_1',
#        'quest_exp_1', 'rich_monster_1', 'death_1', 'revive_1',
#        'exp_recovery_1',
#        ...
#        'combat_same_pledge_cnt_3', 'combat_etc_cnt_3', 'combat_num_opponent_3',
#        'combat_pledge_cnt_4', 'combat_random_attacker_cnt_4',
#        'combat_random_defender_cnt_4', 'combat_temp_cnt_4',
#        'combat_same_pledge_cnt_4', 'combat_etc_cnt_4',
#        'combat_num_opponent_4'],
#       dtype='object', length=141)

# %%
play12 = play[['acc_id','playtime_1','playtime_2','playtime_3','playtime_4']]

# %%
play12
# Out:
#        acc_id  playtime_1  playtime_2  playtime_3  playtime_4
# 0           2   22.919696   22.980553   22.659883   22.973531
# 1           8    4.987936    4.889629    4.653223    4.267014
# 2          17    5.406914    9.048973    7.831832    6.176989
# 3          20    5.526287    7.014944    3.508642    9.538170
# 4          21    6.048253    7.363701    4.966870    3.452466
# ...       ...         ...         ...         ...         ...
# 39995  130295    0.000000    0.000000    0.000000    5.243068
# 39996  130348    0.000000    0.000000    0.000000    0.269175
# 39997  130384    0.000000    0.000000    0.000000    0.477494
# 39998  130461    0.000000    0.000000    0.000000    0.301945
# 39999  130468    0.000000    0.000000    0.000000    1.404393
#
# [40000 rows x 5 columns]

# %%
play12['playtime12'] = play['playtime_1']+play['playtime_2']
# Out:
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
play12['playtime34'] = play12['playtime_3']+play12['playtime_4']
# Out:
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
play12
# Out:
#        acc_id  playtime_1  playtime_2  playtime_3  playtime_4  playtime12  \
# 0           2   22.919696   22.980553   22.659883   22.973531   45.900249
# 1           8    4.987936    4.889629    4.653223    4.267014    9.877565
# 2          17    5.406914    9.048973    7.831832    6.176989   14.455887
# 3          20    5.526287    7.014944    3.508642    9.538170   12.541231
# 4          21    6.048253    7.363701    4.966870    3.452466   13.411954
# ...       ...         ...         ...         ...         ...         ...
# 39995  130295    0.000000    0.000000    0.000000    5.243068    0.000000
# 39996  130348    0.000000    0.000000    0.000000    0.269175    0.000000
# 39997  130384    0.000000    0.000000    0.000000    0.477494    0.000000
# 39998  130461    0.000000    0.000000    0.000000    0.301945    0.000000
# 39999  130468    0.000000    0.000000    0.000000    1.404393    0.000000
#
#        playtime34
# 0       45.633414
# 1        8.920237
# 2       14.008821
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
play12['playsum'] = play12['playtime12']+play12['playtime34']
# Out:
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
play12['play12cha'] = play12['playsum']-play12['playtime12']
# Out:
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
play12['play34cha'] = play12['playsum']-play12['playtime34']
# Out:
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
play12
# Out:
#        acc_id  playtime_1  playtime_2  playtime_3  playtime_4  playtime12  \
# 0           2   22.919696   22.980553   22.659883   22.973531   45.900249
# 1           8    4.987936    4.889629    4.653223    4.267014    9.877565
# 2          17    5.406914    9.048973    7.831832    6.176989   14.455887
# 3          20    5.526287    7.014944    3.508642    9.538170   12.541231
# 4          21    6.048253    7.363701    4.966870    3.452466   13.411954
# ...       ...         ...         ...         ...         ...         ...
# 39995  130295    0.000000    0.000000    0.000000    5.243068    0.000000
# 39996  130348    0.000000    0.000000    0.000000    0.269175    0.000000
# 39997  130384    0.000000    0.000000    0.000000    0.477494    0.000000
# 39998  130461    0.000000    0.000000    0.000000    0.301945    0.000000
# 39999  130468    0.000000    0.000000    0.000000    1.404393    0.000000
#
#        playtime34    playsum  play12cha  play34cha
# ...

# %%
play12[play12==0] = np.nan
# Out:
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\multicampus\Anaconda3\lib\site-packages\pandas\core\frame.py:3515: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)

# %%
play12
# Out:
#        acc_id  playtime_1  playtime_2  playtime_3  playtime_4  playtime12  \
# 0           2   22.919696   22.980553   22.659883   22.973531   45.900249
# 1           8    4.987936    4.889629    4.653223    4.267014    9.877565
# 2          17    5.406914    9.048973    7.831832    6.176989   14.455887
# 3          20    5.526287    7.014944    3.508642    9.538170   12.541231
# 4          21    6.048253    7.363701    4.966870    3.452466   13.411954
# ...       ...         ...         ...         ...         ...         ...
# 39995  130295         NaN         NaN         NaN    5.243068         NaN
# 39996  130348         NaN         NaN         NaN    0.269175         NaN
# 39997  130384         NaN         NaN         NaN    0.477494         NaN
# 39998  130461         NaN         NaN         NaN    0.301945         NaN
# 39999  130468         NaN         NaN         NaN    1.404393         NaN
#
#        playtime34    playsum  play12cha  play34cha
# ...

# %%
play12['playtime12'].min()
# Out:
# 0.002340655217004705

# %%
play12['playtime12'] = play12['playtime12'].fillna(value = 0.002340655217004705)
# Out:
# C:\Users\multicampus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
play12
# Out:
#        acc_id  playtime_1  playtime_2  playtime_3  playtime_4  playtime12  \
# 0           2   22.919696   22.980553   22.659883   22.973531   45.900249
# 1           8    4.987936    4.889629    4.653223    4.267014    9.877565
# 2          17    5.406914    9.048973    7.831832    6.176989   14.455887
# 3          20    5.526287    7.014944    3.508642    9.538170   12.541231
# 4          21    6.048253    7.363701    4.966870    3.452466   13.411954
# ...       ...         ...         ...         ...         ...         ...
# 39995  130295         NaN         NaN         NaN    5.243068    0.002341
# 39996  130348         NaN         NaN         NaN    0.269175    0.002341
# 39997  130384         NaN         NaN         NaN    0.477494    0.002341
# 39998  130461         NaN         NaN         NaN    0.301945    0.002341
# 39999  130468         NaN         NaN         NaN    1.404393    0.002341
#
#        playtime34    playsum  play12cha  play34cha
# ...

# %%
column = df.columns

# %%
len(column)
# Out:
# 141

# %%
column[2]
# Out:
# 'npc_kill_1'

# %%
df[df==0] = np.nan
i=2
for i in range(2,len(df.columns)):
    py = df[df.columns[i]].min()
    print(py)
    print(df.columns[i])
    df[df.columns[i]] = df[df.columns[i]].fillna(py)
    i = i+1
# Out:
# 0.0003379401046725734
# npc_kill_1
# 7.535525139270069e-08
# solo_exp_1
# 2.813902983551669e-07
# party_exp_1
# 7.698160285412411e-06
# quest_exp_1
# 1.0
# rich_monster_1
# 0.2458834656477353
# death_1
# 0.24733689711011106
# revive_1
# 15.0
# exp_recovery_1
# 7.802184056682343e-05
# fishing_1
# 0.00011703276085023526
# private_shop_1
# -83.7287068056479
# game_money_change_1
# 20.0
# enchant_count_1
# 0.002340655217004705
# playtime_2
# 0.0003379401046725734
# npc_kill_2
# 7.535525139270069e-08
# solo_exp_2
# 2.813902983551669e-07
# party_exp_2
# 7.698160285412411e-06
# quest_exp_2
# 1.0
# rich_monster_2
# 0.2458834656477353
# death_2
# 0.24733689711011106
# revive_2
# 15.0
# exp_recovery_2
# 7.802184056682343e-05
# fishing_2
# 0.00027307644198388306
# private_shop_2
# -93.90426966503391
# game_money_change_2
# 20.0
# enchant_count_2
# 0.002340655217004705
# playtime_3
# 0.0003379401046725734
# npc_kill_3
# 7.535525139270069e-08
# solo_exp_3
# 2.813902983551669e-07
# party_exp_3
# ...

# %%
df['npc_kill_1'].min()
# Out:
# 0.0003379401046725734

# %%
py= df[df.columns[2]].min()

# %%
df[df.columns[2]].fillna(py)
# Out:
# 0         0.000338
# 1        26.808113
# 2        25.931158
# 3        27.285960
# 4         4.379366
#            ...
# 39995     0.000338
# 39996     0.000338
# 39997     0.000338
# 39998     0.000338
# 39999     0.000338
# Name: npc_kill_1, Length: 40000, dtype: float64

# %%
df
# Out:
#        acc_id  playtime_1  npc_kill_1  solo_exp_1  party_exp_1  quest_exp_1  \
# 0           2   22.919696         NaN         NaN          NaN          NaN
# 1           8    4.987936   26.808113   28.720862          NaN     0.650061
# 2          17    5.406914   25.931158    4.197880     1.086304     0.700796
# 3          20    5.526287   27.285960    0.204564     0.025327     0.004013
# 4          21    6.048253    4.379366   14.917062          NaN     9.242806
# ...       ...         ...         ...         ...          ...          ...
# 39995  130295         NaN         NaN         NaN          NaN          NaN
# 39996  130348         NaN         NaN         NaN          NaN          NaN
# 39997  130384         NaN         NaN         NaN          NaN          NaN
# 39998  130461         NaN         NaN         NaN          NaN          NaN
# 39999  130468         NaN         NaN         NaN          NaN          NaN
#
# ...
